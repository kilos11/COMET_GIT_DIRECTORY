# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.4/677.4 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 62.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.6/300.6 kB 31.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 15.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 979.1/979.1 kB 42.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.2.0
#     Uninstalling python-box-7.2.0:
#       Successfully uninstalled python-box-7.2.0
# ...

# %% [markdown]
# ##Comet provides an extensive REST API[link text](https://www.comet.com/docs/v2/api-and-sdk/rest-api/overview/) and a Python API[link text](https://www.comet.com/docs/v2/api-and-sdk/python-sdk/reference/API/) object to help you search and export your Comet data. Our goal is to provide a method to perform programmatically any action you can perform in the UI as well as access any logged data.
#
# ##There are two steps to using the Python API method:
#
# ##*Find the Experiment you wish to access using the `API.query()` or `API.get()` methods, both of these methods will return an `APIExperiment()`.*
# ##*Use the `APIExperiment()` methods to access the data logged to this experiment.*

# %% [markdown]
# #**Get Experiments**#
# ##**Get Experiment by Key**##
# ##If you would like to find a single Experiment and you know it's Experiment Key (it can be found in the Single Experiment Page), the easiest way to access the Experiment is using the `API.get()` method:

# %%
import comet_ml

# Create an experiment that we can fetch at a later date
comet_ml.init()
exp = comet_ml.Experiment()

for i in range(100):
        exp.log_metric("accuracy", i, step=i)

exp_key = exp.get_key()
exp.end()

# Fetch the experiment
api = comet_ml.API()
api_experiment = api.get_experiment_by_key(exp_key)

# You can now access the logged data
api_experiment.get_metrics()
# Out:
# Please paste your Comet API key from https://www.comet.com/api/my/settings/
# (api key may not show as you type)
# Comet API key: ··········
# COMET INFO: Valid Comet API Key saved in /root/.comet.config (set COMET_CONFIG to change where it is saved).
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kilos11/general/c7e8d2536cc74658a16be3c7457b7817
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO: Comet.ml Experiment Summary
# COMET INFO: ---------------------------------------------------------------------------------------
# COMET INFO:   Data:
# ...

# %% [markdown]
# ##**Get all Experiments in a project**##
# ##To get all the Experiments in a workspace or project, you can use the `API.get_experiments()` method which will return a list of `APIExperiment()`:

# %%
import comet_ml  # Import the comet_ml library for experiment tracking

PROJECT_NAME = "test-project"  # Define the name of the project
WORKSPACE_NAME = "kilos11"  # Define the name of the workspace

# Initialize comet_ml for experiment tracking
comet_ml.init()

# Create a new experiment in the specified workspace and project
exp = comet_ml.Experiment(workspace=WORKSPACE_NAME,
                          project_name=PROJECT_NAME)

# Log accuracy metrics for 100 steps
for i in range(100):
    # Log accuracy value equal to step number
    exp.log_metric("accuracy", i, step=i)

# Get the unique key for this experiment
exp_key = exp.get_key()

# Initialize the Comet.ml API
api = comet_ml.API()

# Fetch all experiments in the specified workspace
all_experiments_in_workspace = api.get_experiments(WORKSPACE_NAME)

# Fetch all experiments in the specified project within the workspace
all_experiments_in_project = api.get_experiments(WORKSPACE_NAME,
                                                 PROJECT_NAME)
# Out:
# COMET WARNING: As you are running in a Jupyter environment, you will need to call `experiment.end()` when finished to ensure all metrics and code are logged before exiting.
# COMET INFO: Experiment is live on comet.com https://www.comet.com/kilos11/test-project/b5b3f6f7338845a38fb1ea42f0487c66
#
# COMET INFO: Couldn't find a Git repository in '/content' nor in any parent directory. Set `COMET_GIT_DIRECTORY` if your Git Repository is elsewhere.
